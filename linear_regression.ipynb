# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("data/homeprices.csv")

# %%
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel("area")
plt.ylabel("price")

plt.scatter(df["area"], df["price"], marker="+")

# %%
model = LinearRegression()

# %%
model.fit(df[["area"]], df.price)
# Out:
# LinearRegression()

# %%
model.predict([[3300]])
# Out:
# C:\Users\Habib\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# 180616.43835616432

# %%
plt.xlabel("area")
plt.ylabel("price")

plt.scatter(df["area"], df["price"], marker="+")
plt.plot(df.area, model.predict(df[["area"]]))
